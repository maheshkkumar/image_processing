# %%
import time 
import requests
import cv2
import operator
import numpy as np

# Import library to display results
import matplotlib.pyplot as plt
# %matplotlib inline 
# Display images within Jupyter

# %%
# Variables
_url = 'https://api.projectoxford.ai/face/v1.0/detect'
_key = 'bfe4672a06364a60899ed0faab481e15'
_maxNumRetries = 10

# %%
def processRequest( json, data, headers, params = None ):

    """
    Helper function to process the request to Project Oxford

    Parameters:
    json: Used when processing images from its URL. See API Documentation
    data: Used when processing image read from disk. See API Documentation
    headers: Used to pass the key information and the data type request
    """

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print "Message: %s" % ( response.json()['error']['message'] )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print 'Error: failed after retrying!'
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print "Error code: %d" % ( response.status_code )
            print "Message: %s" % ( response.json()['error']['message'] )

        break
        
    return result

# %%
def renderResultOnImage( result, img ):
    
    """Display the obtained results onto the input image"""

    for currFace in result:
        faceRectangle = currFace['faceRectangle']
        cv2.rectangle( img,(faceRectangle['left'],faceRectangle['top']),
                           (faceRectangle['left']+faceRectangle['width'], faceRectangle['top'] + faceRectangle['height']),
                       color = (255,0,0), thickness = 1 )

        faceLandmarks = currFace['faceLandmarks']

        for _, currLandmark in faceLandmarks.iteritems():
            cv2.circle( img, (int(currLandmark['x']),int(currLandmark['y'])), color = (0,255,0), thickness= -1, radius = 1 )

    for currFace in result:
        faceRectangle = currFace['faceRectangle']
        faceAttributes = currFace['faceAttributes']

        textToWrite = "%c (%d)" % ( 'M' if faceAttributes['gender']=='male' else 'F', faceAttributes['age'] )
        cv2.putText( img, textToWrite, (faceRectangle['left'],faceRectangle['top']-15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1 )

# %%
# URL direction to image
urlImage = 'https://raw.githubusercontent.com/Microsoft/ProjectOxford-ClientSDK/master/Face/Windows/Data/identification1.jpg'

# Face detection parameters
params = { 'returnFaceAttributes': 'age,gender', 
           'returnFaceLandmarks': 'true'} 

headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage }
data = None

result = processRequest( json, data, headers, params )
print "Printing result"
print result
# Load the original image, fetched from the URL
arr = np.asarray( bytearray( requests.get( urlImage ).content ), dtype=np.uint8 )
img = cv2.cvtColor( cv2.imdecode( arr, -1 ), cv2.COLOR_BGR2RGB )

renderResultOnImage( result, img )

ig, ax = plt.subplots(figsize=(15, 20))
ax.imshow( img )
# Out:
# Printing result
# [{u'faceId': u'825ba2cb-0b3a-46d5-9c95-46923ada429c', u'faceRectangle': {u'width': 112, u'top': 203, u'height': 112, u'left': 302}, u'faceAttributes': {u'gender': u'male', u'age': 26.4}, u'faceLandmarks': {u'underLipTop': {u'y': 293.8, u'x': 353.5}, u'noseTip': {u'y': 271.9, u'x': 364.5}, u'upperLipBottom': {u'y': 285.8, u'x': 354.2}, u'noseLeftAlarTop': {u'y': 254.9, u'x': 353.2}, u'eyebrowLeftOuter': {u'y': 220.8, u'x': 316.4}, u'eyeLeftBottom': {u'y': 231.7, u'x': 336.7}, u'pupilLeft': {u'y': 228.6, u'x': 337.5}, u'upperLipTop': {u'y': 282.5, u'x': 355.0}, u'eyeLeftInner': {u'y': 231.8, u'x': 344.5}, u'eyeRightInner': {u'y': 239.9, u'x': 381.1}, u'eyeLeftTop': {u'y': 225.9, u'x': 337.8}, u'mouthLeft': {u'y': 275.8, u'x': 326.5}, u'noseRightAlarTop': {u'y': 259.4, u'x': 373.9}, u'eyebrowRightInner': {u'y': 232.6, u'x': 381.9}, u'noseLeftAlarOutTip': {u'y': 261.9, u'x': 344.9}, u'noseRightAlarOutTip': {u'y': 268.5, u'x': 376.8}, u'noseRootRight': {u'y': 239.7, u'x': 372.4}, u'eyeLeftOuter': {u'y': 228.8, u'x': 329.5}, u'underLipBottom': {u'y': 299.8, u'x': 353.0}, u'eyeRightTop': {u'y': 237.4, u'x': 388.6}, u'eyeRightOuter': {u'y': 242.5, u'x': 395.3}, u'noseRootLeft': {u'y': 237.2, u'x': 359.9}, u'eyebrowRightOuter': {u'y': 239.8, u'x': 407.8}, u'eyeRightBottom': {u'y': 243.0, u'x': 387.8}, u'eyebrowLeftInner': {u'y': 225.3, u'x': 356.2}, u'mouthRight': {u'y': 287.5, u'x': 374.9}, u'pupilRight': {u'y': 239.5, u'x': 388.4}}}, {u'faceId': u'5e1e4fbf-94b3-48c1-b192-908b4d227817', u'faceRectangle': {u'width': 91, u'top': 235, u'height': 91, u'left': 398}, u'faceAttributes': {u'gender': u'female', u'age': 28.3}, u'faceLandmarks': {u'underLipTop': {u'y': 313.1, u'x': 439.6}, u'noseTip': {u'y': 290.8, u'x': 442.6}, u'upperLipBottom': {u'y': 301.4, u'x': 441.4}, u'noseLeftAlarTop': {u'y': 279.6, u'x': 435.6}, u'eyebrowLeftOuter': {u'y': 246.9, u'x': 409.8}, u'eyeLeftBottom': {u'y': 261.1, u'x': 424.7}, u'pupilLeft': {u'y': 258.2, u'x': 426.5}, u'upperLipTop': {u'y': 299.6, u'x': 441.4}, u'eyeLeftInner': {u'y': 260.9, u'x': 430.6}, u'eyeRightInner': {u'y': 266.6, u'x': 459.1}, u'eyeLeftTop': {u'y': 256.9, u'x': 425.6}, u'mouthLeft': {u'y': 292.7, u'x': 414.7}, u'noseRightAlarTop': {u'y': 282.5, u'x': 452.1}, u'eyebrowRightInner': {u'y': 256.5, u'x': 459.3}, u'noseLeftAlarOutTip': {u'y': 286.9, u'x': 428.9}, u'noseRightAlarOutTip': {u'y': 290.5, u'x': 454.7}, u'noseRootRight': {u'y': 266.3, u'x': 450.2}, u'eyeLeftOuter': {u'y': 257.5, u'x': 418.9}, u'underLipBottom': {u'y': 315.9, u'x': 439.5}, u'eyeRightTop': {u'y': 262.7, u'x': 466.5}, u'eyeRightOuter': {u'y': 266.1, u'x': 473.1}, u'noseRootLeft': {u'y': 264.6, u'x': 440.1}, u'eyebrowRightOuter': {u'y': 257.6, u'x': 484.7}, u'eyeRightBottom': {u'y': 268.2, u'x': 466.4}, u'eyebrowLeftInner': {u'y': 252.1, u'x': 435.0}, u'mouthRight': {u'y': 301.1, u'x': 464.5}, u'pupilRight': {u'y': 264.5, u'x': 466.7}}}, {u'faceId': u'7246576f-410f-41f0-8ced-bfd4e99622d1', u'faceRectangle': {u'width': 82, u'top': 238, u'height': 82, u'left': 495}, u'faceAttributes': {u'gender': u'female', u'age': 4.9}, u'faceLandmarks': {u'underLipTop': {u'y': 301.5, u'x': 538.0}, u'noseTip': {u'y': 285.5, u'x': 531.5}, u'upperLipBottom': {u'y': 298.3, u'x': 536.5}, u'noseLeftAlarTop': {u'y': 278.9, u'x': 525.2}, u'eyebrowLeftOuter': {u'y': 259.4, u'x': 501.4}, u'eyeLeftBottom': {u'y': 264.0, u'x': 515.5}, u'pupilLeft': {u'y': 262.1, u'x': 515.9}, u'upperLipTop': {u'y': 296.0, u'x': 535.6}, u'eyeLeftInner': {u'y': 262.9, u'x': 521.1}, u'eyeRightInner': {u'y': 259.7, u'x': 547.3}, u'eyeLeftTop': {u'y': 260.9, u'x': 515.3}, u'mouthLeft': {u'y': 296.6, u'x': 522.1}, u'noseRightAlarTop': {u'y': 277.8, u'x': 542.0}, u'eyebrowRightInner': {u'y': 252.8, u'x': 543.2}, u'noseLeftAlarOutTip': {u'y': 285.9, u'x': 521.9}, u'noseRightAlarOutTip': {u'y': 283.2, u'x': 547.0}, u'noseRootRight': {u'y': 262.7, u'x': 537.9}, u'eyeLeftOuter': {u'y': 263.2, u'x': 510.5}, u'underLipBottom': {u'y': 305.9, u'x': 538.6}, u'eyeRightTop': {u' ...

# %%
# Load raw image file into memory
pathToFileInDisk = r'D:\tmp\identification1.jpg'
with open( pathToFileInDisk, 'rb' ) as f:
    data = f.read()

# Face detection parameters
params = { 'returnFaceAttributes': 'age,gender', 
           'returnFaceLandmarks': 'true'} 

headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/octet-stream'

json = None

result = processRequest( json, data, headers, params )

# Load the original image from disk
data8uint = np.fromstring( data, np.uint8 ) # Convert string to an unsigned int array
img = cv2.cvtColor( cv2.imdecode( data8uint, cv2.IMREAD_COLOR ), cv2.COLOR_BGR2RGB )

renderResultOnImage( result, img )

ig, ax = plt.subplots(figsize=(15, 20))
ax.imshow( img )
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-9459295f310c> in <module>()
#       1 # Load raw image file into memory
#       2 pathToFileInDisk = r'D:\tmp\identification1.jpg'
# ----> 3 with open( pathToFileInDisk, 'rb' ) as f:
#       4     data = f.read()
#       5
#
# IOError: [Errno 2] No such file or directory: 'D:\\tmp\\identification1.jpg'
